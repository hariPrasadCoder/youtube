# %%
# Change this url
url = "https://www.cs.columbia.edu/people/faculty/"

# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd

def get_emails_from_webpage(url):
    # Send a request to the URL
    response = requests.get(url)

    # Check if the request was successful
    if response.status_code == 200:
        # Use BeautifulSoup to parse the HTML content
        soup = BeautifulSoup(response.text, 'html.parser')

        # Convert the BeautifulSoup object to a string
        text = str(soup)

        # Regular expression to match email addresses
        email_regex = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b'

        # Find all email addresses using the regular expression
        emails = re.findall(email_regex, text)

        return list(set(emails))  # Use set to remove duplicate emails
    else:
        return f"Failed to retrieve webpage: HTTP {response.status_code}"

emails = get_emails_from_webpage(url)
df = pd.DataFrame()
df['emails'] = emails
df.to_csv('faculty_emails.csv')
df
# Out:
#                     emails
# 0      jae@cs.columbia.edu
# 1    cliff@cs.columbia.edu
# 2    itsik@cs.columbia.edu
# 3   cannon@cs.columbia.edu
# 4     danr@cs.columbia.edu
# ..                     ...
# 61       wing@columbia.edu
# 62  xichen@cs.columbia.edu
# 63     tp2684@columbia.edu
# 64  feiner@cs.columbia.edu
# 65  martha@cs.columbia.edu
#
# [66 rows x 1 columns]
